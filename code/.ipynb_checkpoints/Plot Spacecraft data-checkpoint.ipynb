# %%
# Import libaries
# # As seen in HIEnsembleHindcast/ensemble_analysis.ipynb by L.Barnard ()
# import HUXt as H
# #import HIEnsembleHindcast as heh
# #import HI_analysis as hip
# import testing as TEST
# import tables
# import astropy.units as u
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# import matplotlib.dates as mdates
# import moviepy.editor as mpy
# from moviepy.video.io.bindings import mplfig_to_npimage
# import numpy as np
# import pandas as pd
# import os 
# from astropy.time import Time, TimeDelta
# from astropy.visualization import time_support
# import scipy.stats as st
# from scipy.interpolate import interp1d
# import glob
# import math
# import sunpy.coordinates.sun as sn
# import h5py
# import ensemble as ens
# import matplotlib.ticker as ticker
# from datetime import datetime, timedelta
# from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

# import Analysis2 as ana
# import ACEdata as ace
# import cmath

import ACEdata as ace
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-045c431c9505> in <module>
#      32 # import cmath
#      33
# ---> 34 import ACEdata as ace
#
# ~/Documents/University of Reading/Postgraduate/Research/HUXtOld/code/ACEdata.py in <module>
#       1 # Import libaries
#       2 # As seen in HIEnsembleHindcast/ensemble_analysis.ipynb by L.Barnard ()
# ----> 3 import HUXt as H
#       4 #import HIEnsembleHindcast as heh
#       5 #import HI_analysis as hip
#
# ~/Documents/University of Reading/Postgraduate/Research/HUXtOld/code/HUXt.py in <module>
#      12 from skimage import measure
#      13 import scipy.ndimage as ndi
# ---> 14 from numba import jit
#      15
#      16 mpl.rc("axes", labelsize=16)
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/site-packages/numba/__init__.py in <module>
#      33
#      34 # Re-export decorators
# ---> 35 from numba.core.decorators import (cfunc, generated_jit, jit, njit, stencil,
#      36                                    jit_module)
#      37
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/site-packages/numba/core/decorators.py in <module>
#      10
#      11 from numba.core.errors import DeprecationError, NumbaDeprecationWarning
# ---> 12 from numba.stencils.stencil import stencil
#      13 from numba.core import config, sigutils, registry
#      14
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/site-packages/numba/stencils/stencil.py in <module>
#       9 from llvmlite import ir as lir
#      10
# ---> 11 from numba.core import types, typing, utils, ir, config, ir_utils, registry
#      12 from numba.core.typing.templates import (CallableTemplate, signature,
#      13                                          infer_global, AbstractTemplate)
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# ~/opt/anaconda3/envs/huxt/lib/python3.7/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
ace.plotACEinsitudata(arrivaltime = "2008-12-16 07:00:00", save=True, saveformat='pdf')

# %%
ace.plotACEandSTEREOinsitudata(arrivaltime = "2008-12-16 07:00:00", save=False, saveformat='pdf')
