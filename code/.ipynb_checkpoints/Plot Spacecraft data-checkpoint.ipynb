# %%
# Import libaries
import ACEdata as ace

# %%
# Plot a time-series of in-situ ACE data. Estimated arrival time is shown as a red vertical line.

ace.plotACEinsitudata(arrivaltime = "2008-12-16 07:00:00", save=True, saveformat='png')
